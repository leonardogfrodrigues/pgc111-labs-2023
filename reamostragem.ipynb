# %% [markdown]
# # Prática de Processamento Digital de Imagens (LAB 01)

# %% [markdown]
# Utilizando imagem relogio.tif e faça uma reamostragem de seus pixels para 300, 150 e 72 dpi. Sabe-se que a imagem original possui 1250 dpi. Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
# type your code here
# Python code to read image
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("/content/drive/MyDrive/Mestrado/relogio.tif", cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray', vmin=0, vmax=255);

print('Tamanho da imagem : ',img.shape)

linhas = img.shape[0]
colunas = img.shape[1];
# Resolução original e lista com os diferentes dpi's
dpi_original = 1250
dpi_list = [300, 150, 72]

for dpi in dpi_list:
    # Calculando o fator de escala para a reamostragem
    scale_factor = dpi_original / dpi

    # Calculando as novas dimensões da imagem reamostrada
    new_height = int(linhas / scale_factor)
    new_width = int(colunas / scale_factor)

    # Reamostrando a imagem usando a indexação
    reampled_img = img[::int(scale_factor), ::int(scale_factor)]

    # Plotando as imagens reamostradas
    plt.imshow(reampled_img, cmap='gray', vmin=0, vmax=255)
    plt.title(f"Reamostragem a {dpi} dpi")

    plt.show()
# Out:
# Tamanho da imagem :  (3692, 2812)

# %% [markdown]
# Utilizando a imagem ctskull-256.tif, refaça a quantização de seus pixels utilizando de 7 a 1 bit(s) por pixel. Fazer os cálculos por meio do seu algortimo.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("/content/drive/MyDrive/Mestrado/ctskull-256.tif", cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray', vmin=0, vmax=255);

print('Tamanho da imagem : ',img.shape)

list_bits = [7, 6, 5, 4, 3, 2, 1]

for bits in list_bits:
    # Calculando o valor máximo possível para a nova profundidade de bits
    max_value = 2 ** bits - 1

    # Realizando a quantização usando operações de bit
    quantized_img = ((img >> (8 - bits)) & max_value) * (255 // max_value)

    # Mostrando a imagem quantizada
    plt.imshow(quantized_img, cmap='gray', vmin=0, vmax=255)
    plt.title(f"Imagem Quantizada em {bits} bits")
    plt.show()
# Out:
# Tamanho da imagem :  (452, 374)
